# %% [markdown]
# # Generative Chunking for Non-Generative Retrieval
# - https://github.com/lineality/generative_engineering_nongenerative_search
#
# ## Instructions:
# 1. Type in query below.
# 2. In the file menu above select "Run all" under the Runtime menue.
# - Results will print under each of two search-methods below.
#
#
# ## About
# - Search time ~0.1 sec. in colab.
# - Anyone with a google account should be able to use this open-source tool.
# - This will work on a mobile device too (if less easy to use the interface)
# - This code requires python but no downloads or 3rd party instalations.
# - Free and open source.
# - Both TF-IDF and BM-25 are vanilla (standard library) python requiring no other packages.
# - More source-material can be added (process exaplained below).

# %% [markdown]
# A thrifty, slim, portable, scale-able, fast way to search for policy Q&A
# without the expense of foundation-model AI.
#
# Fancier versions can use embedding models/foundation models (see: https://medium.com/@GeoffreyGordonAshbrook/search-with-non-generative-ai-d0a3cc77164b, https://github.com/lineality/arxiv_explorer_tools) but more portable methods have advantages as well.
#
# Another use-case for document processing and document search, is asking questions about institutional policy.
#
# Todo:
# - Add more documents and speeches.
#
# Proof of Concept G.G.Ashbrook 2024.07.13

# %% [markdown]
# # Add your query here:

# %%
# query = "Trade policy"
# query = "reproductive rights"
# query = "violent crime"
# query = "economic plan"
query = "prescription drug costs"

# %% [markdown]
# # Explanation of process

# %% [markdown]
# ### Procedure:
# 1. (as a preliminary shortcut) the following documents were 'chunked' into 1-2 sentence FAQ responses with the format:
# ```
# Question: , Answer: Source:
# ```
# using claud3.5, using this prompt: e.g.
#
# system prompt:
# ```
# document processing, document summarization
# ```
#
# ```
# Using the following text, please produce as strings in a python list of strings, in this format
#
# [
# "Question: {text here}, Answer: {text here}",
# ...
# ]
# individual short Q&A pairs both for each and every piece of information.
# Importantly this list must include, but is not restricted to, summaries of sections of information, especially: What is Biden's policy on X? What is Harris' plan for pandemic response? Etc.
#
# All information as Q&A AND summaries Q&A.
#
# If the list does not include all questions that can be asked about the document then is not complete.
# Produce a complete list.
#
# Each answer must be short, 1-2 sentences.
# Again the required format is: as strings in a python list of strings:
# [
# "Question: {text here}, Answer: {text here}",
# ...
# ]
#
#
# ```
#
# A followup check may look like this:
# ```
# Is this complete? Does this list contain every policy, position, intent, legitimacy, values, opinion, or action-plan, etc. question that could be asked of the original material? If no, complete the list. Do not repeat past items, add only new items that complete the list.
# ```

# %% [markdown]
# # Sources:
# (exapand to see list)

# %% [markdown]
# source of event transcript sources: https://www.whitehouse.gov/briefing-room/speeches-remarks/

# %% [markdown]
# - https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis
#
# - https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/
#
# -

# %% [markdown]
# (pending)
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/
# 		 							 	 	 		 https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/02/remarks-by-president-biden-before-marine-one-departure-50/
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/01/remarks-by-president-biden-and-vice-president-harris-upon-return-of-americans-detained-in-russia-joint-base-andrews-md/
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/01/remarks-by-vice-president-harris-on-freeing-americans-detained-in-russia/
#
# https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/01/remarks-by-vice-president-harris-at-the-homegoing-service-for-the-late-congresswoman-sheila-jackson-lee/

# %% [markdown]
# Note: this format of tool can be used for other topics as well, e.g.
#
# https://static.project2025.org/2025_MandateForLeadership_FULL.pdf

# %%
corpus = []

# %% [markdown]
# Source: https://joebiden.com/issues/

# %%
# https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis

corpus += [
"Question: What is Biden's overall tax and spending plan?, Answer: Biden's plan would raise $3.375 trillion in new tax revenue while increasing spending by $5.37 trillion over fiscal years 2021-2030. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's tax plan affect households making under $400,000?, Answer: Households with AGI under $400,000 would not see direct tax increases but may see lower investment returns and wages due to corporate tax increases. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the largest areas of new spending in Biden's plan?, Answer: The largest new spending areas are education at $1.9 trillion and infrastructure/R&D at $1.6 trillion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate taxes?, Answer: Biden plans to raise the corporate tax rate, impose a minimum tax on corporate book income, and raise the tax rate on foreign profits. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for education spending?, Answer: Biden proposes $1.9 trillion in education spending, including universal pre-K, expanded funding for Title I schools, and two years of free community college. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's infrastructure plan?, Answer: Biden proposes $1.6 trillion for infrastructure and R&D, including investments in water infrastructure, high-speed rail, municipal transit, and clean energy R&D. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's housing plan?, Answer: Biden proposes $650 billion in new housing spending, including expanding Section 8 housing vouchers and creating new incentives to build affordable housing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's Social Security plan?, Answer: Biden proposes increasing Social Security benefits, especially for low-income retirees, at an estimated cost of $290.7 billion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's healthcare plan?, Answer: Biden's plan aims to improve healthcare access and lower costs, including lowering the Medicare eligibility age to 60 and allowing Medicare to negotiate drug prices. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's immigration policy?, Answer: Biden proposes a path to legal status for undocumented immigrants and aims to restore immigration rates to pre-Trump averages. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is the overall budget impact of Biden's platform from 2021-2030?, Answer: Biden's platform would raise $3.375 trillion in new tax revenue while increasing spending by $5.37 trillion, for a net increase in the primary deficit of $1.975 trillion. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the largest areas of new spending in Biden's plan?, Answer: The largest areas of new spending are education at $1.9 trillion over ten years and infrastructure and R&D at $1.6 trillion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's tax plan affect households making under $400,000?, Answer: Households with AGI of $400,000 or less would not see direct tax increases but would see lower investment returns and wages due to corporate tax increases, with an average decrease in after-tax income of 0.9%. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate taxes?, Answer: Biden plans to raise the corporate tax rate, impose a minimum tax on corporate book income, and raise the tax rate on foreign profits. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How much new revenue would Biden's corporate tax changes generate?, Answer: Biden's corporate tax changes are projected to raise $1,438.5 billion in new revenue over the ten-year budget window. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for education spending?, Answer: Biden proposes $1.9 trillion in new education spending over ten years, including universal pre-K, expanded funding for Title I schools, and two years of free public college for low-income students. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the federal debt by 2050?, Answer: Biden's platform is projected to decrease federal debt by 6.1% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on Social Security?, Answer: Biden proposes increasing Social Security benefits, especially for low-income retirees, including raising the Special Minimum Benefit and switching to the CPI-E for cost of living adjustments. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How much would Biden's Social Security changes cost?, Answer: Biden's Social Security plan is estimated to increase spending by $290.7 billion over the ten-year budget window. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for healthcare?, Answer: Biden's healthcare plan aims to improve access and decrease costs, including lowering the Medicare eligibility age to 60, expanding ACA marketplaces, and allowing Medicare to negotiate drug prices. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's healthcare plan affect federal spending?, Answer: Biden's healthcare plan, including elder care, is estimated to increase spending by $352 billion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on prescription drug prices?, Answer: Biden proposes allowing Medicare to negotiate drug prices and allowing consumers to import drugs from abroad, potentially lowering average prescription drug prices by 60%. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect GDP in 2050?, Answer: The full Biden platform is projected to increase GDP by 0.8% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for housing?, Answer: Biden proposes $650 billion in new housing spending over ten years, including expanding Section 8 housing and creating new incentives to build affordable housing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's tax plan affect the top 0.1% of earners?, Answer: The top 0.1% would see their effective tax rate increase by 12.4 percentage points when including corporate taxes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on immigration?, Answer: Biden proposes a transition to legal status for undocumented immigrants and aims to restore immigration rates to pre-Trump averages. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's immigration plan affect the U.S. population by 2050?, Answer: Biden's immigration plan is projected to increase the U.S. population by 1.64% by 2050. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for infrastructure and R&D?, Answer: Biden proposes $1.6 trillion in new spending on infrastructure and R&D over ten years, including investments in water infrastructure, high-speed rail, and clean energy R&D. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect average hourly wages in 2050?, Answer: The full Biden platform is projected to increase average hourly wages by 1.5% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on capital gains taxes?, Answer: Biden proposes taxing capital gains and dividends at ordinary income rates for high-income earners. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect hours worked in 2030?, Answer: The full Biden platform is projected to decrease hours worked by 2.4% in 2030 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What methodology does PWBM use for economic modeling?, Answer: PWBM uses a dynamic model that accounts for macroeconomic effects, including changes in labor supply, capital formation, and productivity. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's tax plan compare to pre-TCJA tax rates?, Answer: Biden's plan would result in higher effective tax rates than pre-TCJA for the top 1% of earners, but lower rates for those below the 95th percentile of income. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on capital formation by 2050?, Answer: The full Biden platform is projected to decrease the capital stock by 0.4% in 2050 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's plan address climate change?, Answer: Biden's plan includes investments in clean energy R&D and infrastructure, as well as eliminating fossil fuel subsidies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the Child Tax Credit?, Answer: Biden proposes expanding the Child and Dependent Care Tax Credit to cover 50% of child care expenses up to $8,000 per child, limited to two children, and making it fully refundable. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect effective marginal tax rates for high-income earners?, Answer: Biden's plan would significantly increase effective marginal tax rates for those earning over $400,000, primarily due to the 'donut hole' payroll tax policy. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What assumptions does PWBM make about the long-term continuation of Biden's policies?, Answer: PWBM assumes most of Biden's tax and spending policies continue indefinitely, except for some infrastructure and housing provisions that end after 2030. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's plan address income inequality?, Answer: Biden's plan aims to reduce income inequality through progressive taxation, increased social benefits, and investments in education and affordable housing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the Estate Tax?, Answer: Biden proposes eliminating stepped-up basis, which would effectively increase estate taxes for high-value estates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect state tax policies?, Answer: Biden's plan does not directly change state tax policies, but changes in federal taxes and economic conditions could indirectly impact state tax revenues. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for paid leave?, Answer: Biden proposes implementing the FAMILY Act, which is estimated to cost $547 billion over ten years. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of public investment?, Answer: PWBM models public investments as contributing to 'public capital' which complements private capital and labor, boosting productivity over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on interest rates?, Answer: The analysis does not provide specific projections for interest rates, but suggests that changes in debt levels and capital formation would likely impact interest rates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does Biden's plan address the Social Security funding shortfall?, Answer: Biden proposes a new 'Donut Hole' payroll tax on earnings above $400,000 to help fund increased Social Security benefits. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the Earned Income Tax Credit (EITC)?, Answer: Biden proposes expanding the EITC to childless workers aged 65 and older. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the labor force participation rate?, Answer: While not explicitly stated, the projected changes in hours worked suggest Biden's plan could impact labor force participation, particularly for certain demographic groups. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's plan for student debt?, Answer: The analysis does not provide specific details on Biden's student debt plans, focusing instead on his proposals for future education funding. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for behavioral responses to policy changes?, Answer: PWBM's dynamic model incorporates behavioral responses such as changes in labor supply, saving, and investment decisions in response to policy changes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on economic growth in the short term?, Answer: The analysis projects that Biden's full platform would decrease GDP by 0.4% in 2030 compared to the baseline. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different industries?, Answer: While not explicitly analyzed, the plan's focus on clean energy, infrastructure, and healthcare suggests these sectors could see significant impacts. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on international trade?, Answer: The analysis does not provide specific details on Biden's trade policies, focusing primarily on domestic economic policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of healthcare policy changes?, Answer: PWBM uses an integrated health model that captures links between changes in health, demographics, and the broader economy, including insurance choices and health outcomes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income mobility?, Answer: While not explicitly analyzed, the plan's investments in education and focus on progressive taxation could impact income mobility over the long term. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different age groups?, Answer: The plan would have varying effects on different age groups, with policies like lowering the Medicare eligibility age particularly impacting those near retirement. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate offshoring?, Answer: Biden proposes raising taxes on foreign profits of U.S. multinationals, which could discourage offshoring. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for uncertainty in long-term projections?, Answer: The analysis does not explicitly discuss methods for handling uncertainty, but presents results for multiple scenarios to show a range of potential outcomes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income volatility?, Answer: While not explicitly analyzed, expanded social benefits and changes to tax credits could potentially reduce income volatility for some households. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the gig economy?, Answer: The analysis does not specifically address the gig economy, but changes in tax policy and labor market conditions could impact this sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on wealth taxes?, Answer: While Biden does not propose a direct wealth tax, his plans to tax capital gains at ordinary rates and eliminate stepped-up basis would increase taxes on wealth accumulation. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the interaction between federal and state policies?, Answer: The analysis primarily focuses on federal policies, but acknowledges that state and local governments may adjust their policies in response to federal changes. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income inequality by race?, Answer: While the analysis does not provide race-specific projections, policies aimed at low and middle-income households could potentially reduce racial income disparities. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the federal budget deficit over time?, Answer: Biden's plan is projected to increase the deficit in the short term but reduce it in the long term, with debt decreasing by 6.1% by 2050. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on financial regulation?, Answer: The analysis does not provide specific details on Biden's financial regulation policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for demographic changes in its long-term projections?, Answer: PWBM's model incorporates demographic projections, including the effects of immigration policy changes on population growth and age structure. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on entrepreneurship?, Answer: While not explicitly analyzed, changes in tax policy, particularly on business and investment income, could impact entrepreneurship. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different regions of the country?, Answer: The analysis does not provide region-specific projections, but policies focused on particular industries or income groups could have varying regional impacts. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on antitrust enforcement?, Answer: The analysis does not provide specific details on Biden's antitrust policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of education spending on long-term economic outcomes?, Answer: PWBM models education spending as contributing to human capital formation, which increases labor productivity over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on inflation?, Answer: The analysis does not provide specific inflation projections, but changes in government spending, taxes, and economic growth could impact inflation rates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. position in the global economy?, Answer: While not explicitly analyzed, changes in tax policy, R&D investment, and economic growth could impact U.S. global competitiveness. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on monetary policy?, Answer: The analysis does not provide details on Biden's views on monetary policy, as this is primarily the domain of the Federal Reserve. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for technological change in its long-term projections?, Answer: While not explicitly discussed, PWBM's projections likely incorporate assumptions about technological progress, particularly in relation to R&D investments. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income mobility across generations?, Answer: While not explicitly analyzed, investments in education and changes to tax policy could potentially impact intergenerational income mobility. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. energy sector?, Answer: Biden's plan includes significant investments in clean energy R&D and infrastructure, which would likely lead to substantial changes in the energy sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on farm subsidies?, Answer: The analysis does not provide specific details on Biden's policies regarding farm subsidies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of housing policy on the broader economy?, Answer: PWBM models housing assistance as transfers to households, which can affect labor supply and consumption decisions. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on economic mobility for immigrants?, Answer: While not explicitly analyzed, Biden's immigration policies and investments in education could potentially improve economic mobility for immigrants. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the federal government's interest payments?, Answer: While not explicitly stated, changes in debt levels would likely impact the government's interest payments over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on tariffs?, Answer: The analysis does not provide specific details on Biden's tariff policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential economic shocks in its long-term projections?, Answer: The analysis does not explicitly discuss how potential economic shocks are incorporated into the projections. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the U.S. trade balance?, Answer: While not explicitly analyzed, changes in tax policy and economic growth could potentially impact the U.S. trade balance. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different education levels?, Answer: Biden's education proposals, including free public college for low-income students, could significantly impact educational attainment levels. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on the minimum wage?, Answer: The analysis does not provide specific details on Biden's minimum wage policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the effects of R&D spending on productivity growth?, Answer: PWBM likely models R&D spending as contributing to total factor productivity growth, though specific details are not provided. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the distribution of wealth?, Answer: While not explicitly analyzed, changes in tax policy, particularly on capital gains and estates, could impact wealth distribution over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the healthcare industry?, Answer: Biden's healthcare proposals, including drug price negotiations and expanded coverage, would likely lead to significant changes in the healthcare industry. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate governance?, Answer: The analysis does not provide specific details on Biden's corporate governance policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for changes in life expectancy in its long-term projections?, Answer: While not explicitly discussed, PWBM's demographic projections likely incorporate assumptions about changes in life expectancy. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the federal debt-to-GDP ratio?, Answer: While not explicitly stated, the projections of debt and GDP changes imply that Biden's plan would likely decrease the debt-to-GDP ratio over time. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different household types (e.g., single parents, retirees)?, Answer: Various policies, such as expanded child care credits and Social Security changes, would have different impacts on different household types. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on occupational licensing?, Answer: The analysis does not provide specific details on Biden's policies regarding occupational licensing. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the interaction between fiscal and monetary policy?, Answer: The analysis does not explicitly discuss how interactions between fiscal and monetary policy are modeled. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income volatility for different income groups?, Answer: While not explicitly analyzed, expanded social benefits and tax credits could potentially reduce income volatility, particularly for lower-income groups. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. housing market?, Answer: Biden's housing proposals, including expanded housing assistance and first-time homebuyer credits, could significantly impact the housing market. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on worker training programs?, Answer: While not explicitly detailed, Biden's platform likely includes provisions for worker training as part of his education and workforce development plans. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential changes in retirement behavior in its projections?, Answer: While not explicitly discussed, PWBM's model likely incorporates assumptions about how policy changes could affect retirement decisions. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the U.S. manufacturing sector?, Answer: Biden's 'Made in America' plan and infrastructure investments could potentially boost the manufacturing sector, though specific projections are not provided. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on green energy incentives?, Answer: While not explicitly detailed, Biden's plan includes significant investments in clean energy R&D and infrastructure, likely involving green energy incentives. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the potential crowding-out effects of government spending?, Answer: PWBM's model likely accounts for crowding-out effects through changes in interest rates and private investment, though specific details are not provided. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income inequality between urban and rural areas?, Answer: While not explicitly analyzed, policies targeting infrastructure, education, and healthcare could potentially impact urban-rural income disparities. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the gig economy and independent contractors?, Answer: The analysis doesn't specifically address this, but changes in tax policy and labor market conditions could impact gig workers and independent contractors. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on corporate tax havens?, Answer: Biden proposes imposing sanctions on tax havens and raising taxes on foreign profits of U.S. multinationals. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential changes in birth rates in its long-term projections?, Answer: While not explicitly discussed, PWBM's demographic projections likely incorporate assumptions about birth rates. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on small businesses?, Answer: The analysis doesn't provide specific projections for small businesses, but changes in tax policy and economic conditions would likely impact this sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the technology sector?, Answer: While not explicitly analyzed, Biden's R&D investments and potential regulatory changes could significantly impact the tech sector. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on apprenticeship programs?, Answer: The analysis doesn't provide specific details on apprenticeship programs, though these may be part of Biden's broader education and workforce development plans. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the potential effects of climate change on long-term economic projections?, Answer: The analysis doesn't explicitly discuss how climate change effects are incorporated into the economic projections. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the federal government's discretionary spending?, Answer: While not explicitly broken down, Biden's plan includes significant increases in discretionary spending across various areas. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect the pharmaceutical industry?, Answer: Biden's proposals to allow Medicare to negotiate drug prices and to allow drug importation would likely significantly impact the pharmaceutical industry. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on consumer protection regulations?, Answer: The analysis doesn't provide specific details on Biden's consumer protection policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM account for potential changes in migration patterns within the U.S. in its projections?, Answer: While not explicitly discussed, PWBM's model may incorporate assumptions about internal migration patterns. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on the U.S. pension system?, Answer: While not explicitly analyzed, changes to Social Security and overall economic conditions could impact the broader pension system. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How would Biden's plan affect different sectors of the bond market?, Answer: While not explicitly analyzed, changes in government debt levels and economic conditions could impact various sectors of the bond market. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What is Biden's policy on data privacy and cybersecurity?, Answer: The analysis doesn't provide specific details on Biden's data privacy and cybersecurity policies. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: How does PWBM model the potential effects of automation on the labor market in its long-term projections?, Answer: The analysis doesn't explicitly discuss how potential effects of automation are incorporated into the labor market projections. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
"Question: What are the projected effects of Biden's plan on income mobility for different racial and ethnic groups?, Answer: While not explicitly analyzed, policies aimed at education, housing, and progressive taxation could potentially impact income mobility for different racial and ethnic groups. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis",
]

# %% [markdown]
# Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/

# %%
corpus += [
"Question: Where did Vice President Harris speak in Wisconsin?, Answer: Vice President Harris gave this speech at West Allis Central High School in West Allis, Wisconsin. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What was the main purpose of Harris's visit to Wisconsin?, Answer: Harris was in Wisconsin for a political event to campaign for the 2024 presidential election. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What milestone did Harris announce regarding the Democratic nomination?, Answer: Harris announced that she had earned enough delegates to secure the Democratic nomination for president. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How did Harris describe President Biden's accomplishments?, Answer: Harris said Biden's legacy of accomplishment in one term has surpassed most two-term presidents and is 'unmatched in modern history'. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How did Harris contrast her background with Donald Trump's?, Answer: Harris highlighted her experience as a prosecutor and Attorney General taking on predators and fraudsters, contrasting it with Trump's fraud convictions and sexual abuse liability. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris say about the campaign's fundraising?, Answer: Harris announced they just had the best 24 hours of grassroots fundraising in presidential campaign history. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris say would be a defining goal of her presidency?, Answer: Harris said building up the middle class would be a defining goal of her presidency. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How did Harris characterize Trump's economic policies?, Answer: Harris said Trump wants to take the country backward with policies that would weaken the middle class, including cutting Social Security and Medicare. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris say about reproductive rights?, Answer: Harris pledged to stop Trump's 'extreme abortion bans' and sign a law restoring reproductive freedoms if passed by Congress. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What key themes did Harris emphasize for the campaign?, Answer: Harris emphasized themes of fighting for the future, freedom, and opportunity for all Americans. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How many days did Harris say were left until Election Day?, Answer: Harris said there were 105 days left until Election Day. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What did Harris ask supporters to do in the coming months?, Answer: Harris asked supporters to knock on doors, make phone calls, register voters, and work to win the election. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on healthcare?, Answer: Harris supports affordable healthcare for all and opposes ending the Affordable Care Act. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on labor unions?, Answer: Harris supports workers having the freedom to join unions. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's policy on childcare?, Answer: Harris supports making childcare more affordable for families. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on paid family leave?, Answer: Harris supports providing paid family leave. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on retirement security?, Answer: Harris believes every senior should be able to retire with dignity. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on gun control?, Answer: Harris supports passing red flag laws, universal background checks, and an assault weapons ban. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on voting rights?, Answer: Harris supports ensuring every American has the ability to cast their ballot and have it counted. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How does Harris plan to address child poverty?, Answer: Harris believes in creating a future where no child has to grow up in poverty. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's stance on corporate influence in politics?, Answer: Harris criticized Trump for relying on billionaires and big corporations, contrasting it with her 'people-powered' campaign. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: How does Harris plan to approach economic policy?, Answer: Harris emphasized strengthening the middle class as key to making America strong. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
"Question: What is Harris's position on tax policy?, Answer: Harris opposes tax breaks for billionaires and big corporations at the expense of working families. Source: July 23, 2024 West Allis Central High School, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/23/remarks-by-vice-president-harris-at-a-political-event-10/",
]

# %%
# Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/
corpus += [
"Question: What is the main focus of Kamala Harris's campaign? Answer: Harris's campaign focuses on fairness, dignity for all people, freedom, and liberty, emphasizing trust in the people and belief in American ideals. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does Kamala Harris view the concept of collective bargaining? Answer: Harris sees collective bargaining as a noble concept based on fairness, allowing workers to negotiate collectively against big companies for better outcomes. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is Tim Walz's stance on Donald Trump's potential return to office? Answer: Walz believes Trump's return would be worse than before, potentially leading to the elimination of labor unions and workers' collective voices. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is Harris's background in relation to unions? Answer: Harris describes herself as a lifelong supporter of union labor and is honored to have the endorsement of the UAW. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does Harris view the importance of unions for all workers? Answer: Harris believes that even non-union members should be thankful to unions for benefits like the five-day workweek, eight-hour workday, and vacation time. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's stance on abortion rights? Answer: The campaign supports abortion rights, with Walz emphasizing the importance of personal choice and keeping government out of such decisions. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does Harris describe the strength of a leader? Answer: Harris believes the true measure of a leader's strength is based on who they lift up, not who they beat down. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's view on Social Security and Medicare? Answer: The campaign supports protecting Social Security and Medicare, with Walz emphasizing their importance for middle-class Americans. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign view the upcoming election? Answer: They see it as a choice about the direction of the country, with Trump representing a backwards direction and their campaign representing progress. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's message about unity? Answer: The campaign emphasizes collective strength, rejecting division and separation, and believing in the power of people coming together. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does Harris describe her upbringing? Answer: Harris describes growing up in a middle-class family and a community of hard-working people who looked out for each other. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's stance on healthcare? Answer: The campaign supports the Affordable Care Act, with Walz warning that Trump might repeal it, making it harder for people to get health insurance. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign view Trump's handling of the COVID-19 pandemic? Answer: Walz criticizes Trump's response, saying he 'froze in the face of COVID' and his inaction led to deaths and economic downturn. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's message about the future? Answer: The campaign presents itself as focused on the future, particularly the future of American families and the middle class. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign address concerns about crime? Answer: Walz claims that violent crime increased under Trump's presidency, countering Trump's narrative on crime. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's stance on workers' rights? Answer: The campaign strongly supports workers' rights and unions, with both Harris and Walz emphasizing the importance of organized labor. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign view the American promise? Answer: They believe in the promise of America and that people support their campaign because they believe in their hearts in this promise. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's message about hard work? Answer: They embrace hard work, with Harris saying 'Hard work is good work' and emphasizing that they have fun doing hard work because they know what they stand for. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign address concerns about Trump's 'Project 2025'? Answer: Walz warns that this project aims to eliminate labor unions and workers' collective voices if Trump returns to office. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's timeframe for the election? Answer: They emphasize that there are 89 days until the election, calling for intense effort during this period. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is Harris's policy on economic inequality? Answer: Harris supports policies that help families get ahead and enter the middle class, emphasizing fairness and dignity for all workers. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's stance on corporate accountability? Answer: Harris has a record of taking on predators, fraudsters, and transnational gangs, and standing up against billionaires and corporate greed. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign address climate change and environmental issues? Answer: While not explicitly mentioned, the focus on the future and contrast with Trump's policies suggests support for progressive environmental policies. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's position on voting rights? Answer: Although not directly stated, their emphasis on trusting the people and believing in American ideals implies support for protecting and expanding voting rights. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign plan to address housing affordability? Answer: Walz mentions that Trump's policies would make it more difficult to own a home, implying that their campaign would work to make homeownership more accessible. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's stance on education policy? Answer: While not explicitly discussed, their focus on the middle class and future generations suggests support for strengthening public education. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign plan to address income inequality? Answer: Their emphasis on supporting the middle class and standing up to billionaires implies policies aimed at reducing income inequality. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's position on immigration reform? Answer: While not directly addressed, their focus on American ideals and inclusivity suggests a more open and compassionate approach to immigration. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign plan to support small businesses? Answer: Although not explicitly mentioned, their criticism of corporate greed implies support for policies that would benefit small businesses. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's stance on gun control? Answer: While not directly addressed, their mention of rising crime rates under Trump suggests support for stricter gun control measures. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign plan to address racial justice issues? Answer: While not explicitly discussed, their emphasis on equality and justice for all implies support for policies addressing racial inequities. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's position on foreign policy? Answer: Although not directly addressed, their criticism of Trump's leadership suggests a return to more traditional alliance-based foreign policy. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign plan to address the opioid crisis? Answer: While not explicitly mentioned, their focus on community well-being implies support for policies to address substance abuse issues. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: What is the campaign's stance on renewable energy? Answer: Although not directly stated, their forward-looking approach and contrast with Trump's policies suggests support for renewable energy initiatives. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
"Question: How does the campaign plan to support veterans? Answer: While not explicitly mentioned, their emphasis on caring for all Americans suggests support for strong veteran support programs. Source: August 8th 2024. Wayne, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-2/",
            ]

# %%
# Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/
corpus += [
"Question: How did Vice President Harris respond to President Trump's press conference? Answer: Vice President Harris said she was glad Trump finally agreed to a debate on September 10th and that she's looking forward to it. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: Is Vice President Harris open to more debates? Answer: Yes, Harris said she's happy to have a conversation about an additional debate after September 10th. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: How many additional debates did Trump propose? Answer: Trump proposed two more debates. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: Why does Harris think Trump pulled out of the debate with her? Answer: Harris said she's beyond trying to speculate about how Trump thinks. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: How did Harris respond to Trump's criticisms? Answer: Harris said she was too busy talking to voters and didn't hear them. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: What criticism was made about Harris's vice presidential pick? Answer: There was criticism about Harris's VP pick leaving the National Guard at 24 years, with Vance saying he deserted his own troops or colleagues. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: How did Harris respond to the criticism about her VP pick? Answer: Harris said she praises anyone who has presented themselves to serve the country and thinks everyone should. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: When will Harris sit down for her first interview since being the nominee? Answer: Harris said she wants to get an interview scheduled before the end of the month. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: What is Harris's stance on military service? Answer: Harris praises anyone who has presented themselves to serve the country. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: How does Harris interact with the press? Answer: Harris engages with reporters' questions, but also maintains control over the conversation. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: What is Harris's approach to scheduling interviews? Answer: Harris consults with her team and aims to schedule interviews within a specific timeframe. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: How long did the press interaction last? Answer: The interaction lasted about one minute, from 5:25 P.M. to 5:26 P.M. EDT. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: What is Harris's attitude towards debates? Answer: Harris is open to debates and looks forward to participating in them. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: How does Harris prioritize her time? Answer: Harris prioritizes talking to voters over listening to criticism from opponents. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
"Question: What is Harris's communication style? Answer: Harris communicates directly and sometimes uses humor, as evidenced by her initial interaction with the press. Source: August 8th, 2024. Air Force Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/08/remarks-by-vice-president-harris-before-air-force-two-departure-9/",
]

# %%
# Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/
corpus += [
"Question: Who is Kamala Harris's running mate for the 2024 election? Answer: Governor Tim Walz of Minnesota. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on reproductive rights? Answer: She supports a woman's right to choose and pledges to sign a bill restoring reproductive freedoms if elected president. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's plan for healthcare? Answer: She intends to protect and strengthen the Affordable Care Act, opposing Trump's plans to end it. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's position on gun control? Answer: She supports passing an assault weapons ban, universal background checks, and red flag laws. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's approach to the economy? Answer: She prioritizes lowering the cost of living for families, fighting price gouging, and putting the middle class first. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on labor unions? Answer: She strongly supports unions, pledging to pass the PRO Act and end union-busting. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's background before becoming Vice President? Answer: She was a U.S. Senator, Attorney General of California, and a courtroom prosecutor. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's criticism of Donald Trump? Answer: She compares him to perpetrators she's dealt with in her career, citing his fraud convictions and sexual abuse liability. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Project 2025? Answer: It's Trump's agenda that Harris claims will weaken America's middle class through tax breaks for the wealthy and cuts to social programs. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's plan for climate change? Answer: She opposes Trump's intention to surrender the fight against the climate crisis, implying she would continue efforts to address it. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's position on voting rights? Answer: She supports passing the John Lewis Voting Rights Act and the Freedom to Vote Act. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on LGBTQ+ rights? Answer: She supports the freedom to love who you love openly and with pride. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's plan for prescription drug costs? Answer: She plans to take on Big Pharma and cap the cost of prescription drugs for all Americans. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's position on corporate accountability? Answer: She pledges to take on big corporations engaged in illegal price gouging and unfair rent increases. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's view on the Constitution? Answer: She strongly opposes Trump's suggestion to 'terminate' the Constitution, emphasizing its importance. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's message about democracy? Answer: She emphasizes the power of the people in democracy and encourages active participation in the electoral process. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's campaign slogan or recurring phrase? Answer: 'When we fight, we win' is a phrase she uses to rally supporters. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's plan for Social Security and Medicare? Answer: She opposes Trump's alleged intentions to cut these programs, implying she would protect them. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on environmental issues? Answer: She supports the freedom to breathe clean air and drink clean water, indicating a pro-environmental stance. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's approach to governing if elected? Answer: She promises to govern on behalf of all Americans, from red states to blue states, from the heartland to the coasts."
"Question: What is Harris's stance on affordable housing? Answer: She supports a future with affordable housing for Americans. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's position on paid leave? Answer: She advocates for a future that includes paid leave for workers. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris plan to address wealth inequality? Answer: She aims to build a broad-based economy where every American has an opportunity to own a home, start a business, and build wealth. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's view on the role of the middle class in America? Answer: She believes the middle class built the country and that when the middle class is strong, America is strong. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris plan to support seniors? Answer: She fights for a future where every senior can retire with dignity. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on childcare? Answer: She supports making childcare affordable for families. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris characterize her campaign team? Answer: She refers to them as 'joyful warriors' who believe hard work is good work. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's view on the Supreme Court's recent decision regarding presidential immunity? Answer: She expresses concern about the Court's decision that essentially grants immunity to a former president convicted of fraud. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the issue of corporate landlords? Answer: She pledges to take on corporate landlords that unfairly raise rents on working families. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on dictatorships? Answer: She strongly opposes Trump's statement about being a dictator on day one, emphasizing the importance of preserving American democracy. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris view the role of compromise in governance? Answer: While not explicitly stated, her emphasis on governing for all Americans suggests a willingness to find common ground. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's position on education? Answer: While not directly addressed in this speech, her support for affordable education and reducing student loan debt is implied. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris plan to address issues of racial equity? Answer: While not explicitly discussed in this speech, her emphasis on opportunity for all Americans suggests a commitment to racial equity. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on foreign policy? Answer: This speech doesn't address foreign policy directly, which is a notable omission given the vice president's role in international affairs. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the opioid crisis? Answer: This issue isn't directly addressed in the speech, which is a notable omission given its importance in many communities. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's position on immigration reform? Answer: The speech doesn't address immigration policy, which is a significant omission given its importance in national politics. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: How does Harris plan to address cybersecurity threats? Answer: The speech doesn't mention cybersecurity, which is an increasingly important national security issue. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",
"Question: What is Harris's stance on renewable energy and green jobs? Answer: While she mentions opposing the surrender of the fight against climate change, she doesn't provide specific plans for renewable energy or green jobs. Source Aug 7th 2024, Metropolitan Wayne County Airport Detroit, Michigan https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-walz-at-a-campaign-event/",

]

# %%
# Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/
corpus += [
"Question: Who are the main speakers at this event? Answer: The main speakers are Vice President Kamala Harris and Governor Tim Walz of Minnesota. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: Where and when does this event take place? Answer: The event takes place in Eau Claire, Wisconsin on an unspecified date, starting at 2:12 P.M. CDT. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What is the purpose of this event? Answer: This is a campaign event for Kamala Harris's presidential run, where she announces Tim Walz as her running mate. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What is Tim Walz's background? Answer: Tim Walz is the Governor of Minnesota, a former congressman, teacher, coach, and Army National Guard veteran. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What are some key points of Kamala Harris's campaign platform? Answer: Harris emphasizes strengthening the middle class, protecting freedoms like voting and reproductive rights, and opposing Donald Trump's policies. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris describe her approach to the presidency? Answer: Harris says she will work for all Americans, fight for families, freedoms, and the future, and govern on behalf of everyone regardless of political affiliation. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What criticisms does Harris make of Donald Trump? Answer: Harris criticizes Trump's legal issues, his Supreme Court appointments that led to overturning Roe v. Wade, and his stated intentions to be a 'dictator on day one' if re-elected. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What is Project 2025? Answer: Project 2025 is described as a plan by Trump to weaken the middle class through tax breaks for the wealthy and cuts to social programs. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about reproductive rights? Answer: Harris promises to sign a bill restoring Roe v. Wade protections if elected, and criticizes Trump's role in appointing Supreme Court justices who overturned Roe. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Tim Walz describe his background? Answer: Walz describes himself as coming from a small town in Nebraska, serving in the Army National Guard, and working as a teacher and coach before entering politics. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Walz say about Donald Trump? Answer: Walz criticizes Trump for having no understanding of service, weakening the country, and mishandling the COVID-19 pandemic. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about her legal background? Answer: Harris mentions her experience as a prosecutor, district attorney, and attorney general, saying she's dealt with people like Trump throughout her career. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What economic policies does Harris promote? Answer: Harris promotes affordable housing, healthcare, childcare, paid leave, and fighting against corporate price gouging and unfair rent increases. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about climate change? Answer: Harris implies she will continue to fight against the climate crisis, contrasting this with Trump's intention to 'surrender our fight against the climate crisis'. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about gun control? Answer: Harris supports passing universal background checks, red flag laws, and an assault weapons ban. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris describe her vision for America's future? Answer: Harris describes a future focused on worker rights, dignified retirement for seniors, broad-based economic opportunity, and the chance for all Americans to build wealth. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Walz say about freedom? Answer: Walz emphasizes personal freedoms, including healthcare decisions and education choices, criticizing government overreach in these areas. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris address the Supreme Court's recent decision regarding presidential immunity? Answer: Harris criticizes the decision, saying it essentially told Trump he would be immune no matter what he does in the White House. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about the Affordable Care Act? Answer: Harris opposes Trump's intention to end the Affordable Care Act, warning it would return to a time when insurance companies could deny coverage for pre-existing conditions. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris describe her campaign's outreach? Answer: Harris says her campaign will reach out to everyone, from red states to blue states, from the heartland to the coast, and govern on behalf of all Americans. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Walz say about IVF treatments? Answer: Walz shares a personal story about undergoing IVF treatments with his wife, emphasizing the importance of reproductive freedoms. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about voting rights? Answer: Harris supports passing the John Lewis Voting Rights Act and the Freedom to Vote Act to protect voting rights. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris describe the stakes of the upcoming election? Answer: Harris describes the election as a choice between a country of freedom, compassion, and rule of law versus a country of chaos, fear, and hate. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about Trump's statements regarding the Constitution? Answer: Harris criticizes Trump for suggesting to 'terminate the United States Constitution', arguing this disqualifies him from being president again. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about union rights? Answer: Harris supports workers' freedom to join unions, emphasizing this as part of her vision for the future. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris plan to address manufacturing jobs? Answer: Harris plans to continue bringing manufacturing jobs back to America and to communities like Eau Claire. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What is Harris's stance on environmental issues? Answer: Harris supports the freedom to breathe clean air and drink clean water, implying a commitment to environmental protection. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about LGBTQ+ rights? Answer: Harris supports the freedom to love who you love openly and with pride, indicating support for LGBTQ+ rights. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Walz address the issue of book banning? Answer: Walz opposes book banning, stating 'I sure the hell don't need you telling us what books we're going to read.'",
"Question: What does Walz say about gun ownership? Answer: Walz supports the Second Amendment but also believes in commonsense gun violence laws. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris plan to engage young voters? Answer: While not explicitly stated, Harris mentions meeting with young Girl Scout leaders, suggesting an intention to engage and inspire young voters. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Walz say about Trump's running mate? Answer: Walz criticizes Trump's running mate for having a career funded by Silicon Valley billionaires and for writing negatively about their hometown. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris address the issue of prescription drug costs? Answer: Harris plans to cap the cost of prescription drugs for all Americans. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Walz say about compromise in politics? Answer: Walz states he learned how to compromise without compromising his values during his time in Congress. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris plan to address the cost of living? Answer: Harris mentions it will be a day-one priority to fight to bring down prices for everyday items like groceries. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about her approach to corporate accountability? Answer: Harris mentions her past experience taking on big Wall Street banks for fraud and plans to hold corporations accountable for price gouging. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Walz describe the difference between his and Trump's understanding of service? Answer: Walz says Trump has no understanding of service because he's too busy servicing himself. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: What does Harris say about her plans for the Department of Justice? Answer: Harris implies she will not weaponize the Department of Justice against political enemies, contrasting this with Trump's stated intentions. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
"Question: How does Harris address the issue of peaceful protest? Answer: Harris criticizes Trump's stated intention to 'round up peaceful protesters and throw them out of our country', implying her support for the right to peaceful protest. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/",
]

# %%
# Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/
corpus += [
"Question: Who announced their candidacy for president? Answer: Vice President Kamala Harris announced her candidacy for president of the United States. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: Who did Harris choose as her running mate? Answer: Harris chose Governor Tim Walz of Minnesota as her running mate. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' background before becoming Vice President? Answer: Harris served as a prosecutor, district attorney, attorney general of California, and U.S. Senator before becoming Vice President. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Tim Walz's background? Answer: Tim Walz is the governor of Minnesota, a former congressman, teacher, football coach, and Army National Guard veteran. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on healthcare? Answer: Harris supports strengthening and expanding the Affordable Care Act to make healthcare a right for all Americans. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' position on reproductive rights? Answer: Harris strongly supports reproductive freedom and vows to restore reproductive rights nationwide if elected. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's record on reproductive rights? Answer: As governor, Walz signed a law enshrining reproductive freedom as a fundamental right in Minnesota after Roe v. Wade was overturned. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for gun safety? Answer: Harris plans to pass universal background checks, red flag laws, and an assault weapons ban if elected. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's background on gun issues? Answer: Walz is a hunter and gun owner who supports reasonable gun safety laws, having expanded background checks as governor. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to strengthen the middle class? Answer: Harris aims to make strengthening the middle class her defining goal as president, focusing on affordable housing, healthcare, childcare, and paid leave. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on voting rights? Answer: Harris strongly supports expanding voting rights and pledges to pass the John Lewis Voting Rights Act and Freedom to Vote Act. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's record on voting rights? Answer: As governor, Walz signed the most significant expansion of voting rights in Minnesota in over 50 years. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address economic issues? Answer: Harris plans to build a broad-based economy, lower the cost of living, and create opportunities for homeownership and business creation. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' message regarding Donald Trump? Answer: Harris portrays Trump as self-serving, chaotic, and a threat to fundamental freedoms and the middle class. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's criticism of Trump? Answer: Walz criticizes Trump's handling of COVID-19, the economy, and crime, as well as his attempts to restrict freedoms and help the super-rich. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on LGBTQ+ rights? Answer: Harris supports the freedom to love who you love openly and with pride, indicating strong support for LGBTQ+ rights. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's history with LGBTQ+ issues? Answer: As a teacher, Walz supported one of the first openly gay students at his school by becoming a faculty advisor for a gay-straight alliance. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for education? Answer: While not explicitly detailed, Harris suggests support for making education a ticket to the middle class without crippling debt. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's background in education? Answer: Walz was a public school teacher for nearly 20 years, teaching social studies and coaching football. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on climate change? Answer: While not explicitly detailed, Harris mentions supporting clean air and pure water, suggesting a pro-environmental stance. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' approach to bipartisanship? Answer: Harris emphasizes reaching across the aisle to improve people's lives and governing on behalf of all Americans. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's experience with bipartisanship? Answer: Walz served in Congress representing a purple district, working across the aisle on issues like veterans affairs and agriculture. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' vision for America's future? Answer: Harris envisions a future with greater freedom, opportunity, and justice for all, not just some. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Walz describe his values? Answer: Walz emphasizes values of community, generosity towards neighbors, and working for the common good. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on union rights? Answer: While not explicitly stated in this speech, her mention of Walz's work to protect workers' freedom to join unions suggests she supports union rights. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing crime? Answer: While not explicitly detailed in this speech, Harris' background as a prosecutor suggests a focus on law and order. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' approach to foreign policy? Answer: The speech does not explicitly address foreign policy issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for immigration reform? Answer: The speech does not explicitly address immigration policy. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on student loan debt? Answer: While not explicitly detailed, Harris suggests support for making education affordable without crippling debt. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for job creation? Answer: While not explicitly detailed, Harris emphasizes building a broad-based economy where every American has the opportunity to start a business. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on Social Security and Medicare? Answer: While not explicitly stated by Harris, Walz accuses Trump of planning to gut Social Security and Medicare, implying Harris would protect these programs. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing inflation? Answer: Harris mentions bringing down prices that are still too high and lowering the cost of living for American families. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' strategy for winning the election? Answer: Harris plans to reach out to everyone across the country, in red and blue states, rural and urban areas, emphasizing shared values and common interests. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris describe her partnership with Walz? Answer: Harris describes Walz as a partner who can help build a brighter future, unite the nation, and move the country forward. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's criticism of J.D. Vance? Answer: Walz criticizes Vance for his Yale education, Silicon Valley connections, and for writing a book trashing his community, suggesting he's out of touch with Middle America. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris address concerns about being the underdog in the race? Answer: Harris acknowledges being the underdog but claims to have momentum, expressing confidence in knowing what they're up against. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' message about the power of American democracy? Answer: Harris emphasizes that the power is with the people, and that fighting for the ideals of the country is the highest form of patriotism. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris frame the choice voters face in this election? Answer: Harris presents the election as a choice between a country of freedom, compassion, and rule of law versus a country of chaos, fear, and hate. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Walz's stance on personal freedom? Answer: Walz emphasizes respecting neighbors' personal choices and adhering to the principle of 'mind your own damn business,' particularly regarding healthcare decisions. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris address her historic candidacy? Answer: Harris frames her candidacy as an example of the American promise, where two middle-class kids can make it to the White House. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for pandemic response? Answer: The speech does not explicitly address pandemic response plans. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on tax policy? Answer: While not explicitly detailed, Harris criticizes Trump's tax cuts for the wealthy, implying support for a more progressive tax system. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for infrastructure development? Answer: The speech does not explicitly address infrastructure plans, though it mentions Josh Shapiro's reputation for fixing bridges. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to unite the country? Answer: Harris emphasizes seeing neighbors instead of enemies in fellow Americans and plans to govern on behalf of all Americans. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on criminal justice reform? Answer: While not explicitly addressed in this speech, Harris' background as a prosecutor suggests she would have a nuanced approach to criminal justice issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing racial inequality? Answer: The speech does not explicitly address plans for racial inequality, though Harris' emphasis on justice for all implies a commitment to addressing these issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on international trade? Answer: The speech does not explicitly address international trade policies. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting veterans? Answer: While not explicitly detailed, Harris praises Walz's work on veterans' issues in Congress, suggesting support for veteran-friendly policies. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the opioid crisis? Answer: The speech does not explicitly address plans for the opioid crisis. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on marijuana legalization? Answer: The speech does not explicitly address marijuana legalization. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing homelessness? Answer: While not explicitly detailed, Harris mentions support for affordable housing as part of her vision for the future. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support small businesses? Answer: Harris mentions building an economy where every American has the opportunity to start a business, implying support for small business initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on campaign finance reform? Answer: The speech does not explicitly address campaign finance reform. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address income inequality? Answer: While not explicitly detailed, Harris' emphasis on strengthening the middle class and building a broad-based economy implies a focus on reducing income inequality. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for renewable energy development? Answer: While not explicitly detailed, Harris' mention of clean air suggests support for renewable energy initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support working families? Answer: Harris emphasizes support for affordable housing, healthcare, childcare, and paid leave as part of her vision for supporting working families. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on net neutrality? Answer: The speech does not explicitly address net neutrality. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the national debt? Answer: The speech does not explicitly address plans for the national debt. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on farm subsidies and agricultural policy? Answer: The speech does not explicitly address agricultural policy, though Walz's background in representing rural areas suggests some focus on these issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support public education? Answer: While not explicitly detailed, Harris' emphasis on education as a ticket to the middle class suggests strong support for public education. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing climate change? Answer: While not explicitly detailed, Harris' mention of clean air and pure water suggests support for environmental initiatives to address climate change. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support the arts and humanities? Answer: The speech does not explicitly address support for the arts and humanities. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on space exploration and NASA funding? Answer: The speech does not explicitly address space exploration or NASA funding. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the housing crisis? Answer: Harris mentions support for affordable housing as part of her vision for the future, suggesting a focus on addressing housing issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting child care and early education? Answer: Harris mentions support for affordable childcare as part of her vision for the future. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the student debt crisis? Answer: While not explicitly detailed, Harris suggests support for making education affordable without crippling debt. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on nuclear energy? Answer: The speech does not explicitly address nuclear energy policy. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support labor unions? Answer: While not explicitly detailed in this speech, Harris' mention of Walz's work to protect workers' freedom to join unions suggests support for labor unions. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing urban development and renewal? Answer: The speech does not explicitly address urban development plans, though Harris mentions reaching out to urban communities. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support rural communities? Answer: While not explicitly detailed, Harris mentions reaching out to rural communities and Walz's background in representing rural areas suggests a focus on rural issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on corporate regulation? Answer: While not explicitly detailed, Harris' criticism of powerful corporate interests suggests support for stronger corporate regulation. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the opioid crisis? Answer: The speech does not explicitly address plans for the opioid crisis. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting mental health initiatives? Answer: The speech does not explicitly address mental health initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support scientific research and development? Answer: The speech does not explicitly address plans for scientific research and development. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on immigration reform? Answer: The speech does not explicitly address immigration reform policies. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address wealth inequality? Answer: While not explicitly detailed, Harris' emphasis on strengthening the middle class and building a broad-based economy implies a focus on addressing wealth inequality. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting public transportation? Answer: The speech does not explicitly address public transportation initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support STEM education? Answer: While not explicitly detailed, Harris' emphasis on education as a ticket to the middle class suggests support for STEM education initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on term limits for elected officials? Answer: The speech does not explicitly address term limits for elected officials. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address cybersecurity threats? Answer: The speech does not explicitly address plans for cybersecurity. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting minority-owned businesses? Answer: While not explicitly detailed, Harris' mention of opportunities for business creation suggests support for minority-owned businesses. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the gender pay gap? Answer: While not explicitly addressed, Harris' focus on strengthening the middle class and supporting working families suggests attention to issues like the gender pay gap. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on tort reform? Answer: The speech does not explicitly address tort reform. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support veterans' mental health? Answer: While not explicitly detailed, Harris' praise for Walz's work on veterans' issues suggests support for veterans' mental health initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing food insecurity? Answer: The speech does not explicitly address plans for food insecurity, though Walz's work on making school meals free is mentioned. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support the LGBTQ+ community? Answer: Harris expresses support for the freedom to love who you love openly and with pride, indicating strong support for LGBTQ+ rights. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on net neutrality? Answer: The speech does not explicitly address net neutrality. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the national debt? Answer: The speech does not explicitly address plans for the national debt. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting public libraries? Answer: The speech does not explicitly address support for public libraries. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address racial disparities in healthcare? Answer: While not explicitly addressed, Harris' support for expanding healthcare access implies attention to racial disparities in healthcare. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on federal marijuana policy? Answer: The speech does not explicitly address federal marijuana policy. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support Native American communities? Answer: Harris mentions reaching out to Tribal communities, suggesting a focus on supporting Native American issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing the digital divide? Answer: The speech does not explicitly address plans for the digital divide. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support the arts in education? Answer: The speech does not explicitly address support for arts education. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on campaign finance reform? Answer: The speech does not explicitly address campaign finance reform. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address ocean conservation? Answer: While not explicitly addressed, Harris' mention of clean water suggests support for environmental initiatives including ocean conservation. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting community colleges? Answer: While not explicitly detailed, Harris' emphasis on education as a ticket to the middle class suggests support for community colleges. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the rise of artificial intelligence? Answer: The speech does not explicitly address plans for artificial intelligence. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on nuclear weapons policy? Answer: The speech does not explicitly address nuclear weapons policy. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support work-life balance initiatives? Answer: Harris mentions support for paid leave as part of her vision for the future, suggesting a focus on work-life balance. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing the gender gap in STEM fields? Answer: While not explicitly addressed, Harris' focus on education and equality suggests attention to issues like the gender gap in STEM. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support renewable energy jobs? Answer: While not explicitly detailed, Harris' mention of clean air suggests support for renewable energy initiatives, which would likely include job creation. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on charter schools? Answer: The speech does not explicitly address charter schools. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the affordable housing crisis? Answer: Harris mentions support for affordable housing as part of her vision for the future. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting small farms and sustainable agriculture? Answer: While not explicitly addressed, Walz's background in representing rural areas suggests some focus on agricultural issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the rising cost of prescription drugs? Answer: While not explicitly detailed, Harris' emphasis on affordable healthcare suggests attention to prescription drug costs. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on international climate agreements? Answer: While not explicitly addressed, Harris' mention of clean air suggests support for environmental initiatives, potentially including international agreements. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support early childhood education? Answer: While not explicitly detailed, Harris' mention of affordable childcare suggests support for early childhood education initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing the shortage of affordable senior housing? Answer: While not explicitly addressed, Harris' mention of affordable housing could extend to senior housing issues. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support vocational and trade education? Answer: While not explicitly detailed, Harris' emphasis on education as a ticket to the middle class could include support for vocational and trade education. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on federal minimum wage? Answer: While not explicitly stated by Harris, Walz's work to raise the minimum wage is mentioned positively. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the rising cost of college tuition? Answer: While not explicitly detailed, Harris suggests support for making education affordable without crippling debt. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting green energy initiatives? Answer: While not explicitly detailed, Harris' mention of clean air suggests support for green energy initiatives. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address racial disparities in the criminal justice system? Answer: While not explicitly addressed in this speech, Harris' background as a prosecutor suggests she would have a nuanced approach to criminal justice issues, including racial disparities. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on federal funding for Planned Parenthood? Answer: While not explicitly stated, Harris' strong support for reproductive rights suggests she would support federal funding for Planned Parenthood. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support working parents? Answer: Harris emphasizes support for affordable childcare and paid leave as part of her vision for supporting working families. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing the gender pay gap? Answer: While not explicitly addressed, Harris' focus on strengthening the middle class and supporting working families suggests attention to issues like the gender pay gap. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support public school teachers? Answer: While not explicitly detailed, Harris' emphasis on education and Walz's background as a teacher suggest strong support for public school teachers. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on school choice? Answer: The speech does not explicitly address school choice. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the rise of white nationalism? Answer: While not explicitly addressed, Harris' emphasis on unity and rejecting hate suggests opposition to white nationalism. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting historically black colleges and universities (HBCUs)? Answer: The speech does not explicitly address support for HBCUs. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the shortage of affordable housing? Answer: Harris mentions support for affordable housing as part of her vision for the future. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on capital punishment? Answer: The speech does not explicitly address capital punishment. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support small businesses affected by the pandemic? Answer: While not explicitly addressed, Harris' mention of opportunities for business creation suggests support for small businesses, potentially including those affected by the pandemic. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing climate change-induced natural disasters? Answer: While not explicitly detailed, Harris' mention of clean air and pure water suggests support for environmental initiatives, which could include addressing climate change-induced disasters. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support veterans' transition to civilian life? Answer: While not explicitly detailed, Harris' praise for Walz's work on veterans' issues suggests support for veterans' transition programs. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on regulating big tech companies? Answer: While not explicitly addressed, Harris' criticism of powerful corporate interests suggests support for regulating big tech companies. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address police reform? Answer: While not explicitly detailed in this speech, Harris' background as a prosecutor and emphasis on justice suggest she would have a stance on police reform. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on the Electoral College? Answer: The speech does not explicitly address the Electoral College system. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support the manufacturing sector? Answer: While not explicitly detailed, Harris' emphasis on a broad-based economy suggests support for various sectors, including manufacturing. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing the national debt? Answer: The speech does not explicitly address plans for managing the national debt. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support diversity and inclusion initiatives in the workplace? Answer: While not explicitly detailed, Harris' emphasis on equality and opportunity suggests support for diversity and inclusion in the workplace. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on Supreme Court reform? Answer: The speech does not explicitly address Supreme Court reform. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the challenges of an aging population? Answer: While not explicitly addressed, Harris' mention of Medicare suggests attention to issues affecting older Americans. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for supporting the gig economy workers? Answer: The speech does not explicitly address plans for gig economy workers. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the issue of money in politics? Answer: The speech does not explicitly address campaign finance or the influence of money in politics. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' stance on federal legalization of marijuana? Answer: The speech does not explicitly address marijuana legalization at the federal level. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to support America's allies abroad? Answer: The speech does not explicitly address foreign policy or support for international allies. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: What is Harris' plan for addressing the national shortage of affordable child care? Answer: While Harris mentions support for affordable child care, specific plans to address the national shortage are not detailed. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
"Question: How does Harris plan to address the issue of student loan forgiveness? Answer: While Harris mentions making education affordable, specific plans for student loan forgiveness are not detailed in this speech. Source Aug 6th 2024 Temple University Philadelphia, Pennsylvania https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/06/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event/",
]

# %%
# Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/
corpus += [
"Question: Where and when did Vice President Harris give this speech?, Answer: Vice President Harris gave this speech at the Four Seasons Hotel in Houston, Texas on July 31, 2024 at 6:19 P.M. CDT. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: Who introduced Vice President Harris?, Answer: Sima introduced Vice President Harris at the event. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is the main purpose of this event?, Answer: This is a political event, likely a fundraiser or campaign rally, for the upcoming 2024 presidential election. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: How many days until the election at the time of this speech?, Answer: Vice President Harris mentions there are 97 days until the election. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What recent natural disaster did Harris reference?, Answer: Harris mentioned her visit to Houston after Hurricane Beryl. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on climate change?, Answer: Harris states that the administration is committed to tackling the climate crisis, which is fueling increasingly extreme weather events. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' background before becoming Vice President?, Answer: Harris was previously a U.S. Senator, Attorney General of California, and a courtroom prosecutor. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: How does Harris compare herself to Donald Trump?, Answer: Harris contrasts her record of prosecuting fraudsters and predators with Trump's legal issues, including fraud convictions and sexual abuse liability. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' vision for the future of America?, Answer: Harris envisions a future with affordable healthcare, childcare, paid family leave, no child poverty, dignified retirement for seniors, clean air and water, and a strong economy with opportunities for all. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for the middle class?, Answer: Harris plans to take on price gouging, ban hidden fees, cap rent increases, cap prescription drug costs, and make strengthening the middle class a defining goal of her presidency. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Project 2025?, Answer: Project 2025 is described as Trump's plan to weaken the middle class, including cuts to Social Security and Medicare, tax breaks for billionaires, and ending the Affordable Care Act. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What freedoms does Harris say are under assault?, Answer: Harris mentions assaults on voting rights, gun safety, LGBTQ+ rights, reproductive rights, and the freedom to learn America's full history. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on abortion rights?, Answer: Harris strongly supports reproductive freedom and vows to fight for a woman's right to choose, promising to sign a law restoring reproductive freedoms if elected president. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' view on the recent Supreme Court decision regarding Trump?, Answer: Harris criticizes the decision, suggesting it gives Trump implicit authority to act without consequences if he returns to the White House. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What does Harris say about Trump's plans if re-elected?, Answer: Harris states that Trump has vowed to be a dictator on day one, weaponize the Department of Justice against political enemies, and has even suggested 'terminating' the Constitution. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What question does Harris say voters face in this election?, Answer: Harris says voters face the question: 'What kind of country do we want to live in? A country of freedom, compassion, and rule of law or a country of chaos, fear, and hate?'",
"Question: How does Harris describe the current state of their campaign?, Answer: Harris describes their campaign as the underdog in the race, despite enthusiasm and historic grassroots fundraising. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' call to action for supporters?, Answer: Harris calls on supporters to not throw up their hands but to roll up their sleeves, emphasizing that hard work is good work. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' policy on healthcare?, Answer: Harris supports affordable healthcare and intends to protect the Affordable Care Act, contrasting with Trump's alleged plan to end it. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for gun control?, Answer: Harris supports passing universal background checks, red flag laws, and an assault weapons ban to address gun violence. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on voting rights?, Answer: Harris supports passing the John Lewis Voting Rights Act and the Freedom to Vote Act to protect voting rights. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' position on LGBTQ+ rights?, Answer: Harris supports the freedom to love who you love openly and with pride, indicating support for LGBTQ+ rights. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for addressing poverty?, Answer: Harris believes in a future where no child grows up in poverty and where every person has the opportunity to build wealth. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on environmental issues?, Answer: Harris supports ensuring clean water to drink and clean air to breathe for all people, indicating a commitment to environmental protection. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for senior citizens?, Answer: Harris believes in a future where all seniors can retire with dignity, suggesting support for programs benefiting the elderly. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' approach to corporate regulation?, Answer: Harris plans to take on corporate landlords, cap rent increases, and challenge big pharmaceutical companies to reduce prescription drug costs. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' view on Trump's Supreme Court appointments?, Answer: Harris criticizes Trump's Supreme Court appointments, stating they were intended to overturn Roe v. Wade protections. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on immigration?, Answer: While not directly addressed in this speech, Harris implies opposition to Trump's alleged plan to 'round up peaceful protesters and throw them out of our country.'",
"Question: What is Harris' message about democracy?, Answer: Harris emphasizes the importance of preserving democracy, stating that fundamental freedoms and democracy itself are on the ballot in this election. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' campaign slogan?, Answer: While not explicitly stated as a slogan, Harris ends with 'When we fight, we win!', which could be considered a campaign motto. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for pandemic response?, Answer: This speech does not directly address pandemic response plans. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' policy on education?, Answer: While not extensively discussed, Harris mentions supporting the freedom to learn and acknowledge America's full history. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on foreign policy?, Answer: This speech does not directly address foreign policy issues. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for job creation?, Answer: Harris emphasizes building a strong economy where every person has the opportunity to build a business, own a home, and build intergenerational wealth. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' position on tax policy?, Answer: Harris criticizes Trump's alleged plan to give tax breaks to billionaires and big corporations, implying she opposes such measures. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on racial justice?, Answer: While not explicitly discussed, Harris' support for voting rights and learning America's full history suggests a commitment to racial justice. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for infrastructure?, Answer: This speech does not directly address infrastructure plans. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' position on campaign finance reform?, Answer: While not directly addressed, Harris praises grassroots fundraising efforts, potentially indicating support for small-donor contributions. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on student debt?, Answer: This speech does not directly address student debt issues. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for renewable energy?, Answer: While not explicitly discussed, Harris' commitment to addressing climate change suggests support for renewable energy initiatives. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' position on criminal justice reform?, Answer: While not extensively discussed in this speech, Harris' background as a prosecutor and her criticism of Trump suggests support for rule of law and potential reforms. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for childcare?, Answer: Harris supports affordable childcare as part of her vision for America's future. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on labor rights?, Answer: While not explicitly discussed, Harris' support for the middle class and paid family leave suggests a pro-labor stance. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' position on international trade?, Answer: This speech does not directly address international trade policies. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for addressing income inequality?, Answer: Harris emphasizes strengthening the middle class and providing opportunities for all to build wealth, suggesting a focus on reducing income inequality. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' stance on marijuana legalization?, Answer: This speech does not directly address marijuana legalization. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' position on national security?, Answer: This speech does not directly address national security issues. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
"Question: What is Harris' plan for veterans?, Answer: While not extensively discussed, Harris mentions protecting veterans from scams by for-profit colleges, suggesting a commitment to veterans' welfare. Source July 31 2024 Four Seasons Hotel Houston, Texas https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/07/31/remarks-by-vice-president-harris-at-a-political-event-houston-tx/",
]

# %%
# Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/

corpus += [
"Question: How many times has Vice President Harris visited North Carolina since taking office? Answer: Harris has visited North Carolina 16 times since becoming Vice President. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' vision for the economy? Answer: Harris envisions an 'opportunity economy' where everyone can compete and succeed, regardless of their background. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' plan for lowering food costs? Answer: Harris plans to pass a federal ban on price gouging for food and penalize companies that exploit crises to raise prices. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address high healthcare costs? Answer: Harris plans to cap insulin prices at $35 per month, limit total prescription drug costs to $2,000 annually for seniors, and allow Medicare to negotiate drug prices. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on the Affordable Care Act? Answer: Harris supports maintaining and strengthening the Affordable Care Act, which provides healthcare coverage to 45 million Americans. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' plan for addressing the housing shortage? Answer: Harris aims to build 3 million new affordable homes and rentals by the end of her first term as president. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to help first-time homebuyers? Answer: Harris proposes providing $25,000 to first-time homebuyers to help with down payments on new homes. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What tax credits does Harris plan to restore and expand? Answer: Harris plans to restore and expand the Earned Income Tax Credit and the Child Tax Credit to benefit middle-class and working Americans. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How much tax relief does Harris propose for families with newborns? Answer: Harris proposes providing $6,000 in tax relief to families during the first year of a child's life. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' criticism of Donald Trump's economic plans? Answer: Harris criticizes Trump's plans to impose a national sales tax on imports and give tax cuts to billionaires and corporations, which she argues will hurt middle-class families. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address medical debt? Answer: Harris plans to prevent medical debt from affecting credit scores and work with states to cancel medical debt for millions of Americans. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' background in addressing housing issues? Answer: As California Attorney General, Harris drafted a homeowner bill of rights and won $20 billion for California families during the foreclosure crisis. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to make the housing market more competitive? Answer: Harris plans to crack down on corporate landlords who use anticompetitive practices to artificially inflate rental prices. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on union membership? Answer: Harris supports workers' right to join unions if they choose to do so. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to support small businesses? Answer: Harris plans to cut unnecessary regulatory red tape and encourage innovative technologies while protecting consumers and creating a stable business environment. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' view on the current state of the US economy? Answer: Harris believes the US economy is the strongest in the world, citing job creation and reduced inflation, but acknowledges many Americans still struggle with high costs. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address poverty? Answer: Harris believes no child should grow up in poverty and plans to implement policies that strengthen the middle class and provide economic opportunities. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on retirement security? Answer: Harris believes that after years of hard work, people should be able to retire with dignity. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address inflation? Answer: Harris highlights that inflation is down to under 3 percent and plans to continue efforts to lower costs for American families. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' criticism of Trump's Project 2025 agenda? Answer: Harris argues that Trump's agenda would increase mortgage costs, undo progress on lowering prescription drug prices, and hurt middle-class Americans. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to create jobs? Answer: Harris plans to bring together labor, small businesses, and major companies to invest in America and create good jobs. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on corporate profits? Answer: Harris criticizes companies making record profits while keeping prices high and plans to take action against those not playing by the rules. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address supply chain issues? Answer: While Harris notes supply chains have improved since the pandemic, she plans to take further action to lower costs that remain high. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' background in consumer protection? Answer: As California Attorney General, Harris went after companies that illegally increased prices and won over $1 billion for consumers. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to support working parents? Answer: Harris proposes tax relief for families with newborns and plans to make childcare more affordable. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on deficit reduction? Answer: Harris states she will implement her tax cut plans while also reducing the deficit. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address wealth inequality? Answer: Harris aims to create an economy where everyone has the opportunity to build wealth for themselves and their children. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' view on the role of competition in the economy? Answer: Harris believes competition is the lifeblood of the economy and plans to foster more competition to lower prices for consumers. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address the needs of seniors? Answer: Harris plans to protect Medicare and Social Security, and has already implemented measures to lower prescription drug costs for seniors. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on technological innovation? Answer: Harris plans to encourage innovative technologies while also protecting consumers and creating consistent rules for businesses. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on infrastructure investment? Answer: Harris mentions historic investments in infrastructure as part of the administration's economic achievements. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to support American manufacturing? Answer: Harris highlights investments in chips manufacturing and plans to continue supporting American industry. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' position on clean energy? Answer: Harris mentions historic investments in clean energy as part of the administration's economic strategy. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address bureaucracy in government? Answer: Harris plans to cut needless bureaucracy and unnecessary regulatory red tape to encourage business growth. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' view on the role of government in economic growth? Answer: Harris believes in a partnership between government, labor, and business to achieve broad-based growth and ensure America leads the world. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to support the middle class? Answer: Harris considers building up the middle class a defining goal of her presidency, believing a strong middle class means a strong America. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on salary adequacy? Answer: Harris believes a salary should be enough to provide a good quality of life for a family. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address economic disparities? Answer: Harris aims to remove barriers to opportunity so anyone can access the tools and resources necessary to start a business or advance their career. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' background in economic policy? Answer: Harris references her experience as California Attorney General in tackling economic issues like predatory lending and price gouging. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to ensure economic growth benefits all Americans? Answer: Harris aims to create an 'opportunity economy' where everyone can compete and have a real chance to succeed, regardless of their background. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on transparency in healthcare pricing? Answer: Harris plans to demand transparency from middlemen operating between pharmaceutical companies and insurance companies to lower drug prices. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris view the connection between housing and financial security? Answer: Harris sees homeownership as a symbol of hard work and financial security, representing what people can do for their children. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' approach to economic challenges faced by young parents? Answer: Harris proposes tax relief and support for families in the first year of a child's life, recognizing the high costs associated with raising a newborn. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: How does Harris plan to address the needs of renters? Answer: Harris plans to build more affordable rental properties and crack down on anticompetitive practices by corporate landlords. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
"Question: What is Harris' stance on corporate responsibility? Answer: Harris believes most businesses contribute positively to the economy, but plans to take action against those exploiting consumers or engaging in unfair practices. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/",
]

# %%
# Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/
corpus += [
"Question: When and where did Vice President Harris give this speech?, Answer: Vice President Harris gave this speech on August 22, 2024 at the United Center in Chicago, Illinois during the Democratic National Convention. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What personal anecdote did Harris share about her mother?, Answer: Harris shared that her mother, Shyamala Harris, came to the US from India at age 19 to pursue her dream of being a scientist who would cure breast cancer. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her early childhood?, Answer: Harris said she grew up moving a lot, with joyful memories of a home filled with laughter and music. Her parents later split up when she was in elementary school. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What values did Harris say she learned growing up?, Answer: Harris said she learned values of community, faith, and treating others with kindness, respect and compassion from her family and community. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Why did Harris become a prosecutor?, Answer: Harris became a prosecutor to protect people like her friend Wanda, who had been sexually abused, because she believes everyone has a right to safety, dignity and justice. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach as a prosecutor?, Answer: Harris said she charged cases in the name of the people, believing a harm against any one person is a harm against all. She stated her entire career she's only had one client: the people. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about uniting Americans?, Answer: Harris promised to be a president for all Americans, putting country above party and self. She said she would unite people around their highest aspirations. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about Donald Trump?, Answer: Harris called Trump an 'unserious man' but said the consequences of putting him back in the White House would be extremely serious. She criticized his actions after losing the 2020 election. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about reproductive rights?, Answer: Harris criticized Trump for appointing Supreme Court justices who overturned Roe v. Wade. She pledged to sign a bill restoring reproductive freedom if passed by Congress. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about immigration and border security?, Answer: Harris pledged to pass a bipartisan border security bill that Trump had his allies kill. She said she would create an earned pathway to citizenship and secure the border. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about foreign policy?, Answer: Harris pledged to strengthen global alliances, stand with Ukraine against Russian aggression, support Israel's right to defend itself, work towards peace in Gaza, and confront threats from Iran. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris describe her vision for America?, Answer: Harris described an America that moves forward, where anything is possible, people care for one another, and unity brings strength. She emphasized optimism, freedom, and upholding democratic ideals. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about the middle class?, Answer: Harris said building a strong middle class would be a defining goal of her presidency. She pledged to create an 'opportunity economy' where everyone has a chance to compete and succeed. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What tax policy did Harris propose?, Answer: Harris proposed a middle-class tax cut that would benefit over 100 million Americans, contrasting it with what she called Trump's tax hikes on the middle class. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about climate change?, Answer: Harris mentioned the freedom to breathe clean air and drink clean water, free from pollution that fuels the climate crisis, as one of the fundamental freedoms at stake in the election. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about gun violence?, Answer: Harris mentioned the freedom to live safe from gun violence in schools, communities and places of worship as one of the fundamental freedoms at stake in the election. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about LGBTQ+ rights?, Answer: Harris mentioned the freedom to love who you love openly and with pride as one of the fundamental freedoms at stake in the election. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about voting rights?, Answer: Harris said the election provides an opportunity to pass the John Lewis Voting Rights Act and the Freedom to Vote Act. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about healthcare?, Answer: Harris criticized Trump for trying to eliminate the Affordable Care Act and protections for people with pre-existing conditions. She pledged to lower healthcare costs. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about education?, Answer: Harris said she would not let Trump eliminate the Department of Education that funds public schools or end programs like Head Start for preschool and childcare. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her husband Doug?, Answer: Harris thanked Doug for being an incredible partner and father, wishing him a happy anniversary and expressing her love. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Who did Harris mention as the vice presidential nominee?, Answer: Harris mentioned 'Coach Tim Walz' as the vice presidential nominee, saying he would be an incredible vice president. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her experience as Attorney General of California?, Answer: Harris said she took on big banks, delivered $20 billion for middle-class families facing foreclosure, and helped pass a homeowner bill of rights. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris describe her approach to leadership?, Answer: Harris said she would be a president who leads and listens, is realistic and practical, and always fights for the American people. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about Social Security and Medicare?, Answer: Harris pledged to protect Social Security and Medicare, contrasting this with Trump's attempts to cut these programs. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about small businesses and entrepreneurs?, Answer: Harris promised to provide access to capital for small-business owners, entrepreneurs, and founders as part of her economic plan. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about housing policy?, Answer: Harris pledged to end America's housing shortage, though she did not provide specific details in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about artificial intelligence and space?, Answer: Harris said she would ensure America, not China, wins the competition for the 21st century in areas like space and artificial intelligence. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris address the issue of national security?, Answer: Harris promised to ensure America always has the strongest, most lethal fighting force in the world and to fulfill obligations to care for troops and their families. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about NATO?, Answer: Harris criticized Trump for threatening to abandon NATO and said she would stand strong with NATO allies. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris describe her experience in foreign affairs?, Answer: Harris said as vice president she has confronted threats to security, negotiated with foreign leaders, strengthened alliances, and engaged with troops overseas. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about the situation in Gaza?, Answer: Harris called the situation devastating, emphasized the need to end the war, secure Israel, release hostages, end suffering in Gaza, and support Palestinian rights to dignity and self-determination. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris contrast her approach to foreign leaders with Trump's?, Answer: Harris said she would not cozy up to tyrants and dictators like Kim Jong Un, who she claimed are rooting for Trump because he is easy to manipulate. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her background and its influence on her politics?, Answer: Harris emphasized her middle-class upbringing and how it shapes her commitment to building a strong middle class and creating opportunities for all Americans. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris frame the choice voters face in the election?, Answer: Harris framed the election as a choice between moving forward with optimism and faith versus going back to policies and approaches she associates with Trump and his allies. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about unity and common ground among Americans?, Answer: Harris emphasized that Americans have more in common than what separates them, and that in unity there is strength. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris conclude her speech?, Answer: Harris concluded by calling on Americans to fight for the country they love, uphold their responsibilities as citizens, and write the next chapter in America's story through voting and civic engagement. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her plan for economic growth?, Answer: Harris mentioned bringing together labor, workers, small businesses, entrepreneurs, and American companies to create jobs and grow the economy. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris address the issue of national debt?, Answer: Harris criticized Trump's tax plans, saying they would add $5 trillion to the national debt, but did not specify her own plan for managing national debt. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to criminal justice?, Answer: While Harris mentioned her background as a prosecutor, she did not outline specific criminal justice policies or reforms in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris address climate change policy?, Answer: Harris mentioned freedom from pollution that fuels the climate crisis, but did not detail specific climate policies or plans. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to healthcare reform?, Answer: Beyond criticizing attempts to repeal the Affordable Care Act, Harris did not outline specific healthcare reform policies. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: How did Harris address the issue of income inequality?, Answer: While Harris emphasized building the middle class, she did not specifically address policies to tackle income inequality. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about education policy beyond K-12?, Answer: Harris did not address higher education or college affordability policies in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris mention any specific policies for job creation or workforce development?, Answer: While Harris spoke about economic growth, she did not detail specific job creation or workforce development policies. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to trade policy?, Answer: Harris did not address trade policy or international economic relationships in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris mention any policies related to technology regulation or digital privacy?, Answer: Apart from mentioning AI competition, Harris did not address technology regulation or digital privacy policies. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to drug policy or addressing addiction?, Answer: Harris did not address drug policy or plans to combat addiction in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris mention any policies related to infrastructure development?, Answer: Harris did not specifically address infrastructure development plans in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to campaign finance reform?, Answer: Harris did not address campaign finance reform or related policies in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris mention any policies related to renewable energy or energy independence?, Answer: While mentioning climate change broadly, Harris did not detail specific renewable energy or energy independence policies. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to federal budget priorities?, Answer: Beyond criticizing certain Trump policies, Harris did not outline her specific federal budget priorities. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris address policies related to childcare or family leave?, Answer: Apart from mentioning Head Start, Harris did not detail policies for childcare or family leave. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to agriculture or rural development?, Answer: Harris did not specifically address agriculture or rural development policies in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris mention any policies related to veterans' affairs?, Answer: While mentioning honoring troops, Harris did not detail specific policies for veterans' affairs. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: What did Harris say about her approach to mental health policy?, Answer: Harris did not address mental health policies or initiatives in this speech. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
"Question: Did Harris mention any policies related to election security or voting system reforms?, Answer: Beyond mentioning voting rights acts, Harris did not detail specific election security or voting system reform policies. Source: August 22, 2024 United Center Chicago, Illinois https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/22/remarks-by-vice-president-harris-during-keynote-address-at-the-democratic-nation-convention/",
]

# %%
# Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/
corpus += [
"Question: Where and when did Vice President Harris give this speech?, Answer: Vice President Harris gave this speech at a campaign event in Milwaukee, Wisconsin on August 20, 2024. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What event had just occurred before Harris' speech?, Answer: The Democratic National Convention delegates had just completed their roll call and nominated Harris and Coach Walz to be the next president and vice president. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How many days until the election did Harris mention?, Answer: Harris mentioned there were 77 days until the election. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What is Harris' view on the competitiveness of the upcoming election?, Answer: Harris believes it will be a tight race until the very end, requiring hard work to win. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris characterize the difference between her campaign and Trump's?, Answer: Harris says her campaign is focused on the future, while Trump's is focused on the past. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What are some key policy areas Harris mentions focusing on?, Answer: Harris mentions affordable healthcare, childcare, housing, paid leave, and building an opportunity economy. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What is Harris' plan for lowering the cost of living?, Answer: Harris plans to bring down grocery costs by ensuring competitive markets, cap prescription drug costs, and address high housing costs. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What tax plan does Harris propose?, Answer: Harris proposes giving 100 million Americans a tax cut, including $6,000 to families during a child's first year. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What does Harris say about Trump's 'Project 2025'?, Answer: Harris says Trump's plan would give tax breaks to billionaires and corporations, cut Social Security and Medicare, and impose a national sales tax. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What is Harris' stance on abortion rights?, Answer: Harris strongly supports abortion rights and promises to sign a bill restoring Roe v. Wade protections if elected. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris characterize Trump's potential second term?, Answer: Harris warns that Trump has vowed to be a dictator and weaponize the Department of Justice against political enemies. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What does Harris say about the Constitution in relation to Trump?, Answer: Harris criticizes Trump for calling for the 'termination of the Constitution' and says he should never again be president. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris describe the stakes of the upcoming election?, Answer: Harris says the stakes are higher than in 2016 or 2020, partly due to a Supreme Court decision about presidential immunity. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What does Harris say about the promise of America?, Answer: Harris says the promise of America makes it possible for her and Coach Walz, two middle-class kids, to be on the presidential ticket. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris end her speech?, Answer: Harris ends by asking the audience if they believe in freedom, opportunity, and the promise of America, and if they are ready to fight for it. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What is Harris' plan for first-time homebuyers?, Answer: Harris announced a plan to build millions of new homes and help first-time homebuyers with down payments. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris plan to address prescription drug costs?, Answer: Harris plans to take on Big Pharma and cap the cost of prescription medication for all Americans. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What does Harris say about Trump's abortion stance?, Answer: Harris criticizes Trump for saying he has 'no regrets' about ending Roe v. Wade and mentions over 20 Trump abortion bans. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What other freedoms does Harris say are under attack?, Answer: Harris mentions attacks on voting rights, gun safety, and LGBTQ+ rights. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris characterize her campaign's approach to hard work?, Answer: Harris says they like hard work and that hard work is good work. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What does Harris say about looking out for each other?, Answer: Harris emphasizes caring for one another, referencing 'love thy neighbor' and seeing strangers as neighbors. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris describe her and Coach Walz's backgrounds?, Answer: Harris describes herself as born to a working mom in Oakland, and Walz as a son of the Nebraska plains who worked on a farm. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What does Harris say about the power of democracy?, Answer: Harris says the beauty of democracy is that each person has the power to answer what kind of country they want to live in. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: How does Harris contrast her vision with Trump's?, Answer: Harris asks if people want to live in a country of chaos, fear, and hate, or one of freedom, compassion, and rule of law. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
"Question: What does Harris say about patriotism?, Answer: Harris believes the highest form of patriotism is fighting for the ideals of our country. Source: August 20, 2024 Fiserv Forum Milwaukee, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/20/remarks-by-vice-president-harris-at-a-campaign-event-in-milwaukee-wi/",
]

# %% [markdown]
# https://democrats.org/where-we-stand/party-platform/
#
# https://democrats.org/wp-content/uploads/2020/08/2020-Democratic-Party-Platform.pdf

# %% [markdown]
# # Vanilla TF-IDF Code

# %%
# -*- coding: utf-8 -*-



"""
vanilla_TF-IDF_v5.ipynb

This notebook is based on:
- https://medium.com/@coldstart_coder/understanding-and-implementing-tf-idf-in-python-a325d1301484
- https://www.kaggle.com/code/tylerpoff/understanding-and-implementing-tf-idf-in-python/notebook
"""

import math
import time



"""# query"""
query = query

corpus_unsplit = corpus



def term_frequency(word, document):
    return document.count(word) / len(document)
tf = term_frequency

# # non-plus-1 variant ("unsafe" variant)
# def inverse_document_frequency_unsafe(word, corpus):
#     count_of_documents = len(corpus)
#     count_of_documents_with_word = sum([1 for doc in corpus if word in doc])
#     idf = math.log10(count_of_documents/count_of_documents_with_word)
#     return idf

# sklearn variant
def inverse_document_frequency(word, corpus):
    count_of_documents = len(corpus) + 1
    count_of_documents_with_word = sum([1 for doc in corpus if word in doc]) + 1
    idf = math.log10(count_of_documents/count_of_documents_with_word) + 1
    return idf

idf = inverse_document_frequency

def TF_IDF(word, document, corpus):
    return tf(word, document) * idf(word, corpus)


"""# corpus of documents"""
split_corpus = [c.split() for c in corpus_unsplit]
num_documents = len(split_corpus)


"""### Optional Sample Target Word Analysis"""

"""
optional
"""
# target_word = "Expert"

# print("searching for the word '%s'"%target_word)
# for i, document in enumerate(split_corpus):
#     tf_score = tf(target_word, document)
#     idf_score = idf(target_word, split_corpus)
#     tf_idf_score = TF_IDF(target_word, document, split_corpus)

#     print("document %s: '%s'\n    tf score: %s\n    idf score: %s\n    tf_idf score:%s"%(i, document, tf_score, idf_score, tf_idf_score))
#     print("-"*30)

"""## word to vector mappings"""

"""
 create the word to vector mappings,
 we want each word to map to a unique point in our word vectors.
combine the complete corpus into a single list of words; remove duplicates.
use position in this list as the index for a word vector
"""
word_set = list(set(sum(split_corpus, [])))
# create a lookup for each word to it's index,
word_to_index = {word:i for i, word in enumerate(word_set)}

num_words = len(word_set)


"""## create the word vectors"""
# create an empty list to store our word vectors
word_vectors = []
for document in split_corpus:
    # for our new document create a new word vector
    new_word_vector = [0 for i in range(num_words)]

    # now we loop through each word in our document and compute the tf-idf score and populate our vector with it,
    # we only care about words in this document because words outside of it will remain zero
    for word in document:
        # get the score
        tf_idf_score = TF_IDF(word, document, split_corpus)
        # next get the index for this word in our word vector
        word_index = word_to_index[word]
        # populate the vector
        new_word_vector[word_index] = tf_idf_score

    # don't forget to add this new word vector to our list of existing word_vectors
    word_vectors.append(new_word_vector)


"""## one word vector in comparision to document"""
# # inspection
# print(corpus_unsplit[0])
# print(word_vectors[0])


"""## <b>Searching with TF-IDF Sparse Vectors</b>"""
query_keywords = query.split()

# now we loop through each documents word vector, get the tf-idf score for each keyword, sum them up and that is our tf-idf for that document,
# we keep track of the best document and return that as our result,
tf_idf_scores = []
best_document_index = 0
best_tf_idf = 0

for i, word_vector in enumerate(word_vectors):
    document_tf_idf_score_for_query = 0
    for word in query_keywords:
        # first do a check, does this word appear in our split_corpus of documents?
        # if not skip this keyword
        if word not in word_set:
            continue

        # get the index for this keyword and directly pull it from the word vector
        word_index = word_to_index[word]
        document_tf_idf_score_for_query += word_vector[word_index]
    tf_idf_scores.append(document_tf_idf_score_for_query) # keep track of all tf_idf scores, just in case we want to review them,

    """
    optional:
    top N list...TODO
    """
    # does this tf_idf score for this document beat our previous best?
    if document_tf_idf_score_for_query > best_tf_idf:
        best_tf_idf = document_tf_idf_score_for_query
        best_document_index = i

# from pprint import pprint
# # then print out our results
# # print("results of query: ", query)
# print("best tf_idf score sum for query: ", best_tf_idf)
# print("best document: ", corpus_unsplit[best_document_index])
# print("complete list of tf_idf scores: ", tf_idf_scores)

# pprint(tf_idf_scores)
# pprint(corpus_unsplit)



def search_top_n(query, corpus, n):
    query_keywords = query.split()

    tf_idf_scores = []
    for i, word_vector in enumerate(word_vectors):
        document_tf_idf_score_for_query = 0
        for word in query_keywords:
            if word not in word_set:
                continue

            word_index = word_to_index[word]
            document_tf_idf_score_for_query += word_vector[word_index]
        tf_idf_scores.append((document_tf_idf_score_for_query, i))

    # Sort the TF-IDF scores in descending order
    tf_idf_scores.sort(reverse=True)

    # Extract the document indices from the top-N results
    top_n_document_indices = [index for _, index in tf_idf_scores[:n]]

    # Return the top-N documents and their TF-IDF scores
    top_n_documents = [corpus[index] for index in top_n_document_indices]
    top_n_tf_idf_scores = [score for score, _ in tf_idf_scores[:n]]

    return top_n_documents, top_n_tf_idf_scores

# %% [markdown]
# # Use TF-IDF

# %%
# Set This
how_many_results = 5

# Search
top_n = how_many_results
start_time = time.monotonic()  # timer
top_n_documents, top_n_tf_idf_scores = search_top_n(query, corpus_unsplit, top_n)
end_time = time.monotonic()  # timer
elapsed_time = end_time - start_time  # timer

print(f"Top-{top_n} results for query: {query}")
for i, (document, score) in enumerate(zip(top_n_documents, top_n_tf_idf_scores)):
    print(f"Result {i+1}:")
    print(f"TF-IDF score: {score}")
    print(f"Document: {document}\n")
# timer
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Top-5 results for query: prescription drug costs
# Result 1:
# TF-IDF score: 0.3583454143290076
# Document: Question: What is Biden's policy on prescription drug prices?, Answer: Biden proposes allowing Medicare to negotiate drug prices and allowing consumers to import drugs from abroad, potentially lowering average prescription drug prices by 60%. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis
#
# Result 2:
# TF-IDF score: 0.23179805755150323
# Document: Question: How does Harris address the issue of prescription drug costs? Answer: Harris plans to cap the cost of prescription drugs for all Americans. Source Aug 7th 2024 Eau Claire Event District, Wisconsin https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/07/remarks-by-vice-president-harris-and-governor-tim-walz-at-a-campaign-event-eau-clarie-wi/
#
# Result 3:
# TF-IDF score: 0.21300362045273274
# ...

# %% [markdown]
# # BM-25 Code

# %%
#!/usr/bin/env python
"""
https://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf
    BM25: https://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf
    https://github.com/dorianbrown/rank_bm25
    https://github.com/dorianbrown/rank_bm25/blob/master/rank_bm25.py
"""

import math
import numpy as np
from multiprocessing import Pool, cpu_count

"""
All of these algorithms have been taken from the paper:
Trotmam et al, Improvements to BM25 and Language Models Examined

Here we implement all the BM25 variations mentioned.
"""


class BM25:
    def __init__(self, corpus, tokenizer=None):
        self.corpus_size = 0
        self.avgdl = 0
        self.doc_freqs = []
        self.idf = {}
        self.doc_len = []
        self.tokenizer = tokenizer

        if tokenizer:
            corpus = self._tokenize_corpus(corpus)

        nd = self._initialize(corpus)
        self._calc_idf(nd)

    def _initialize(self, corpus):
        nd = {}  # word -> number of documents with word
        num_doc = 0
        for document in corpus:
            self.doc_len.append(len(document))
            num_doc += len(document)

            frequencies = {}
            for word in document:
                if word not in frequencies:
                    frequencies[word] = 0
                frequencies[word] += 1
            self.doc_freqs.append(frequencies)

            for word, freq in frequencies.items():
                try:
                    nd[word]+=1
                except KeyError:
                    nd[word] = 1

            self.corpus_size += 1

        self.avgdl = num_doc / self.corpus_size
        return nd

    def _tokenize_corpus(self, corpus):
        pool = Pool(cpu_count())
        tokenized_corpus = pool.map(self.tokenizer, corpus)
        return tokenized_corpus

    def _calc_idf(self, nd):
        raise NotImplementedError()

    def get_scores(self, query):
        raise NotImplementedError()

    def get_batch_scores(self, query, doc_ids):
        raise NotImplementedError()

    def get_top_n(self, query, documents, n=5):

        assert self.corpus_size == len(documents), "The documents given don't match the index corpus!"

        scores = self.get_scores(query)
        top_n = np.argsort(scores)[::-1][:n]
        return [documents[i] for i in top_n]


class BM25Okapi(BM25):
    def __init__(self, corpus, tokenizer=None, k1=1.5, b=0.75, epsilon=0.25):
        self.k1 = k1
        self.b = b
        self.epsilon = epsilon
        super().__init__(corpus, tokenizer)

    def _calc_idf(self, nd):
        """
        Calculates frequencies of terms in documents and in corpus.
        This algorithm sets a floor on the idf values to eps * average_idf
        """
        # collect idf sum to calculate an average idf for epsilon value
        idf_sum = 0
        # collect words with negative idf to set them a special epsilon value.
        # idf can be negative if word is contained in more than half of documents
        negative_idfs = []
        for word, freq in nd.items():
            idf = math.log(self.corpus_size - freq + 0.5) - math.log(freq + 0.5)
            self.idf[word] = idf
            idf_sum += idf
            if idf < 0:
                negative_idfs.append(word)
        self.average_idf = idf_sum / len(self.idf)

        eps = self.epsilon * self.average_idf
        for word in negative_idfs:
            self.idf[word] = eps

    def get_scores(self, query):
        """
        The ATIRE BM25 variant uses an idf function which uses a log(idf) score. To prevent negative idf scores,
        this algorithm also adds a floor to the idf value of epsilon.
        See [Trotman, A., X. Jia, M. Crane, Towards an Efficient and Effective Search Engine] for more info
        :param query:
        :return:
        """
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (q_freq * (self.k1 + 1) /
                                               (q_freq + self.k1 * (1 - self.b + self.b * doc_len / self.avgdl)))
        return score

    def get_batch_scores(self, query, doc_ids):
        """
        Calculate bm25 scores between query and subset of all docs
        """
        assert all(di < len(self.doc_freqs) for di in doc_ids)
        score = np.zeros(len(doc_ids))
        doc_len = np.array(self.doc_len)[doc_ids]
        for q in query:
            q_freq = np.array([(self.doc_freqs[di].get(q) or 0) for di in doc_ids])
            score += (self.idf.get(q) or 0) * (q_freq * (self.k1 + 1) /
                                               (q_freq + self.k1 * (1 - self.b + self.b * doc_len / self.avgdl)))
        return score.tolist()


class BM25L(BM25):
    def __init__(self, corpus, tokenizer=None, k1=1.5, b=0.75, delta=0.5):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus, tokenizer)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log(self.corpus_size + 1) - math.log(freq + 0.5)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            ctd = q_freq / (1 - self.b + self.b * doc_len / self.avgdl)
            score += (self.idf.get(q) or 0) * (self.k1 + 1) * (ctd + self.delta) / \
                     (self.k1 + ctd + self.delta)
        return score

    def get_batch_scores(self, query, doc_ids):
        """
        Calculate bm25 scores between query and subset of all docs
        """
        assert all(di < len(self.doc_freqs) for di in doc_ids)
        score = np.zeros(len(doc_ids))
        doc_len = np.array(self.doc_len)[doc_ids]
        for q in query:
            q_freq = np.array([(self.doc_freqs[di].get(q) or 0) for di in doc_ids])
            ctd = q_freq / (1 - self.b + self.b * doc_len / self.avgdl)
            score += (self.idf.get(q) or 0) * (self.k1 + 1) * (ctd + self.delta) / \
                     (self.k1 + ctd + self.delta)
        return score.tolist()


class BM25Plus(BM25):
    def __init__(self, corpus, tokenizer=None, k1=1.5, b=0.75, delta=1):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus, tokenizer)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log(self.corpus_size + 1) - math.log(freq)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score

    def get_batch_scores(self, query, doc_ids):
        """
        Calculate bm25 scores between query and subset of all docs
        """
        assert all(di < len(self.doc_freqs) for di in doc_ids)
        score = np.zeros(len(doc_ids))
        doc_len = np.array(self.doc_len)[doc_ids]
        for q in query:
            q_freq = np.array([(self.doc_freqs[di].get(q) or 0) for di in doc_ids])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score.tolist()


"""
BM25Adpt and BM25T are a bit more complicated than the previous algorithms here. Here a term-specific k1
parameter is calculated before scoring is done
"""

class BM25Adpt(BM25):
    def __init__(self, corpus, k1=1.5, b=0.75, delta=1):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log((self.corpus_size + 1) / freq)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score

    def get_top_n(self, query, documents, n=5):

        assert self.corpus_size == len(documents), "The documents given don't match the index corpus!"

        scores = self.get_scores(query)
        top_n = np.argsort(scores)[::-1][:n]
        return [documents[i] for i in top_n]

class BM25T(BM25):
    def __init__(self, corpus, k1=1.5, b=0.75, delta=1):
        # Algorithm specific parameters
        self.k1 = k1
        self.b = b
        self.delta = delta
        super().__init__(corpus)

    def _calc_idf(self, nd):
        for word, freq in nd.items():
            idf = math.log((self.corpus_size + 1) / freq)
            self.idf[word] = idf

    def get_scores(self, query):
        score = np.zeros(self.corpus_size)
        doc_len = np.array(self.doc_len)
        for q in query:
            q_freq = np.array([(doc.get(q) or 0) for doc in self.doc_freqs])
            score += (self.idf.get(q) or 0) * (self.delta + (q_freq * (self.k1 + 1)) /
                                               (self.k1 * (1 - self.b + self.b * doc_len / self.avgdl) + q_freq))
        return score


    def get_top_n(self, query, documents, n=5):

        assert self.corpus_size == len(documents), "The documents given don't match the index corpus!"

        scores = self.get_scores(query)
        top_n = np.argsort(scores)[::-1][:n]
        return [documents[i] for i in top_n]

# %%
"""
https://github.com/dorianbrown/rank_bm25
https://pypi.org/project/rank-bm25/
https://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf

"""
# !pip install -q git+https://git@github.com/dorianbrown/rank_bm25.git
# from rank_bm25 import BM25Okapi

import time


# # Tokenize the documents

# tokenized_corpus = [doc.split(" ") for doc in corpus]

# # Create a BM25 object
# bm25 = BM25Okapi(tokenized_corpus)

# # Tokenize the query
# tokenized_query = query.split(" ")

# # Calculate BM25 scores for the query
# scores = bm25.get_scores(tokenized_query)

# # Print the scores
# for i, score in enumerate(scores):
#     print(f"Document {i}: {score}")

# %% [markdown]
#  # Use BM-25

# %%
# Set This
how_many_results = 5

# Preprocessing Text
start_time = time.monotonic()  # timer
tokenized_corpus = [doc.split(" ") for doc in corpus]
bm25 = BM25Okapi(tokenized_corpus)  # Create a BM25 object
tokenized_query = query.split(" ")  # Tokenize the query

# Search
top_n = bm25.get_top_n(tokenized_query, corpus, n=how_many_results)
end_time = time.monotonic()  # timer
elapsed_time = end_time - start_time   # timer

# Print
for i in top_n:
    print(i)
# timer
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Question: How does Harris plan to address high healthcare costs? Answer: Harris plans to cap insulin prices at $35 per month, limit total prescription drug costs to $2,000 annually for seniors, and allow Medicare to negotiate drug prices. Source: Aug 16th 2024 Wake Tech Community College Raleigh, North Carolina https://www.whitehouse.gov/briefing-room/speeches-remarks/2024/08/16/remarks-by-vice-president-harris-at-a-campaign-event-in-raleigh-nc/
# Question: What is Biden's policy on prescription drug prices?, Answer: Biden proposes allowing Medicare to negotiate drug prices and allowing consumers to import drugs from abroad, potentially lowering average prescription drug prices by 60%. Source: https://budgetmodel.wharton.upenn.edu/issues/2020/9/14/biden-2020-analysis
# ...
